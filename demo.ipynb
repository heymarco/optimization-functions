# %%
from optifn.callables import *

# %%
functions = [
    Ackley(),
    Bukin6(),
    Hartman6(),
    CrossInTray(),
    Levy(),
    Bohachevsky(),
    Matyas(),
    ThreeHump(),
]

# %%
for f in functions:
    print(f.name() + "-Function")
    print(f.description())
    f.plot_2d()
    print("********\n")
# Out:
# Ackley-Function
# The Ackley function is widely used for testing optimization algorithms. In its two-dimensional form, as shown in https://www.sfu.ca/~ssurjano/ackley.html, it is characterized by a nearly flat outer region, and a large hole at the centre. The function poses a risk for optimization algorithms, particularly hillclimbing algorithms, to be trapped in one of its many local minima.
# ********
#
# Bukin6-Function
# The sixth Bukin function has many local minima, all of which lie in a ridge.
# ********
#
# Hartman6-Function
# The 6-dimensional Hartmann function has 6 local minima.
# Error: hartman6 is 6-dimensional
# ********
#
# Cross In Tray-Function
# The Cross-in-Tray function has multiple global minima. It is shown here (https://www.sfu.ca/~ssurjano/crossit.html) with a smaller domain in the second plot, so that its characteristic cross will be visible.
# ********
#
# Levy-Function
# More information available under https://www.sfu.ca/~ssurjano/levy.html
# (10000, 2)
# ...
